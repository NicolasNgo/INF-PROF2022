# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasNgo/INF-PROF2022/blob/main/Practical_Work_2_%5BCORRECTION%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Teaching Unit INF-PROF: Programming fundamentals for health data**
#
# ## **Practical Work 2 - Introduction to pandas**
# Learning objectives:
#
# 1. Creation of dataFrames
# 2. Manipulation of a dataFrame
# 3. Transformation of the values

# %% [markdown]
# ## **1. Creation of a DataFrame**

# %% [markdown]
# To create a DataFrame, you have to first import the pandas library.
# Then use the constructor `DataFrame()`. In Python, if you want to use some function from an imported library, you have to use the appropriate prefix. By default, the prefix will be the name of the library.

# %%
import pandas 

df = pandas.DataFrame(data = [[2, 3], [5, 8], [9, 10]], index = ['row1', 'row2', 'row3'], columns = ['col1', 'col2'])
print(df)
# Out:
#       col1  col2
# row1     2     3
# row2     5     8
# row3     9    10

# %% [markdown]
# But you can also use alias, when importing the library you specify an alias that will be use instead of the library's name.

# %%
import pandas as pd

df = pd.DataFrame(data = [[2, 3], [5,8], [9, 10]], index = ['row1', 'row2', 'row3'], columns = ['col1', 'col2'])
print(df)
# Out:
#       col1  col2
# row1     2     3
# row2     5     8
# row3     9    10

# %% [markdown]
# If you don't want to use any prefix, you can also import the library with the '*' caracter. This way you won't have to use any prefix, BUT if you import two libraries with two functions which has the same name you could have some surprise so be carefull.

# %%
from pandas import *

df = DataFrame(data = [[2, 3], [5, 8], [9, 10]], index = ['row1', 'row2', 'row3'], columns = ['col1', 'col2'])

print(df)

# %% [markdown]
# You can find the Python documentation for DataFrames [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)

# %% [markdown]
# ## **Exercise 1 - Creation of a DataFrame from a dictionary**

# %% [markdown]
# **Build a DataFrame from the following dictionary.**
#
#
# 1.   Build a DataFrame with the dictionary.
# 2.   Display the 5 first rows of the DataFrame with 2 different ways.
# 3.   Use the column `Names` as indexes of the DataFrames.
# 4.   Display the row associated with Pierre.
# 5.   Add the following observation to the DataFrame:
# `{Names: Nicolas, Measures: 12.3, Center: '1'}`.
# 6.   Give the overall mean measurement.
# 7.   Give the mean measurement of each center.
# 8.   Add the following observations from a third center to the DataFrame.
# `'Names': ['Marius', 'Robert', 'Karim'], 'Measures': [15.3, 3.1, 1.5]`
#
#
# ```
# dict1 = {
#   'Names': ['Jean', 'Marie', 'Joseph', 'Marthe', 'Jacob', 'Marc', 'Paul', 'Pierre', 'Ismael', 'David', 'Mathieu'],
#   'Measures': [12.5, 18.0, 10.0, 13.2, 3.2, 5.7, 12.0, 6.0, 7.0, 14.5, 17.6],
#   'Center': ['1', '2', '2', '1', '2', '2', '1','2', '1', '2', '2']
# }
# ```

# %% [markdown]
# ## **Correction of exercise 1**

# %%
# Task 1 - Build a DataFrame with the dictionary

# First we must create the dictionary
dict1 = {
  'Names': ['Jean', 'Marie', 'Joseph', 'Marthe', 'Jacob', 'Marc', 'Paul', 'Pierre', 'Ismael', 'David', 'Mathieu'],
  'Measures': [12.5, 18.0, 10.0, 13.2, 3.2, 5.7, 12.0, 6.0, 7.0, 14.5, 17.6],
  'Center': ['1', '2', '2', '1', '2', '2', '1','2', '1', '2', '2']
}
print('The dictionary', dict1)

# To create the dataframe we first need to import pandas
import pandas as pd

# Then we create the dataFrame by giving the dictionary as an argument of the build-in constructor DataFrame
df = pd.DataFrame(dict1)
print(df)
# Out:
# The dictionary {'Names': ['Jean', 'Marie', 'Joseph', 'Marthe', 'Jacob', 'Marc', 'Paul', 'Pierre', 'Ismael', 'David', 'Mathieu'], 'Measures': [12.5, 18.0, 10.0, 13.2, 3.2, 5.7, 12.0, 6.0, 7.0, 14.5, 17.6], 'Center': ['1', '2', '2', '1', '2', '2', '1', '2', '1', '2', '2']}
#       Names  Measures Center
# 0      Jean      12.5      1
# 1     Marie      18.0      2
# 2    Joseph      10.0      2
# 3    Marthe      13.2      1
# 4     Jacob       3.2      2
# 5      Marc       5.7      2
# 6      Paul      12.0      1
# 7    Pierre       6.0      2
# 8    Ismael       7.0      1
# 9     David      14.5      2
# 10  Mathieu      17.6      2

# %%
# Task 2 - Display the 5 first rows of the DataFrame with 2 different ways

# First way to print the first 5 rows is to use the slicing capacity of the DataFrame
df.iloc[0:5]
# Out:
#     Names  Measures Center
# 0    Jean      12.5      1
# 1   Marie      18.0      2
# 2  Joseph      10.0      2
# 3  Marthe      13.2      1
# 4   Jacob       3.2      2

# %%
# Second way is to use the method head of the DataFrame
df.head()
# Out:
#     Names  Measures Center
# 0    Jean      12.5      1
# 1   Marie      18.0      2
# 2  Joseph      10.0      2
# 3  Marthe      13.2      1
# 4   Jacob       3.2      2

# %%
# Third task - Use the column 'Names' as indexes of the DataFrame

# The index can be seen as row names or identifiants. By default Python will use numbers as index (if no other indexes are provided)
# You can set a specific index after the creation of the DataFrame with the `set_index` method of DataFrame
df = df.set_index('Names')
df
# Out:
#          Measures Center
# Names
# Jean         12.5      1
# Marie        18.0      2
# Joseph       10.0      2
# Marthe       13.2      1
# Jacob         3.2      2
# Marc          5.7      2
# Paul         12.0      1
# Pierre        6.0      2
# Ismael        7.0      1
# David        14.5      2
# Mathieu      17.6      2

# %%
# This way you can search for a specific row by giving the index of the row instead of the rowNumber.

# %%
# Task 4 - Display the row associated with Pierre
# Since we used the names of the patients as indexes, we can now use directly the names to display the row
df.loc['Pierre']

# Otherwise we would have to use this syntax
# df[df['Names'] == 'Pierre']

# To display only the measurement
print('Pierre has a measure of %.2f' % df.loc['Pierre'].Measures)
# Out:
# Pierre has a measure of 6.00

# %%
# Task 5 - Add the following observation to the DataFrame
# {'Names': 'Nicolas', 'Measures': 12.3, 'Center': '1' }

# Create a single rowed dataFrame and concatenate the two 
new_df = pd.DataFrame({'Measures':12.3, 'Center':'1'}, index = ['Nicolas'])
df = df.append(new_df)

print(df)
# Out:
#          Measures Center
# Jean         12.5      1
# Marie        18.0      2
# Joseph       10.0      2
# Marthe       13.2      1
# Jacob         3.2      2
# Marc          5.7      2
# Paul         12.0      1
# Pierre        6.0      2
# Ismael        7.0      1
# David        14.5      2
# Mathieu      17.6      2
# Nicolas      12.3      1

# %%
# Task 6 - Give the overall mean
help(pd.DataFrame.mean)

print('Overall mean is %f' % df.Measures.mean())
print('Another way to calculate the overall mean of %f' % df['Measures'].mean())
# Out:
# Help on function mean in module pandas.core.generic:
#
# mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs)
#     Return the mean of the values over the requested axis.
#
#     Parameters
#     ----------
#     axis : {index (0), columns (1)}
#         Axis for the function to be applied on.
#     skipna : bool, default True
#         Exclude NA/null values when computing the result.
#     level : int or level name, default None
#         If the axis is a MultiIndex (hierarchical), count along a
#         particular level, collapsing into a Series.
#     numeric_only : bool, default None
#         Include only float, int, boolean columns. If None, will attempt to use
#         everything, then use only numeric data. Not implemented for Series.
#     **kwargs
#         Additional keyword arguments to be passed to the function.
#
#     Returns
#     -------
#     Series or DataFrame (if level specified)
#
# Overall mean is 11.000000
# ...

# %%
# Task 7 - Give the mean measure of each center
# To do so we will use another method of the DataFrame which is groupby

help(pd.DataFrame.groupby)
# Out:
# Help on function groupby in module pandas.core.frame:
#
# groupby(self, by=None, axis: 'Axis' = 0, level: 'Level | None' = None, as_index: 'bool' = True, sort: 'bool' = True, group_keys: 'bool' = True, squeeze: 'bool | lib.NoDefault' = <no_default>, observed: 'bool' = False, dropna: 'bool' = True) -> 'DataFrameGroupBy'
#     Group DataFrame using a mapper or by a Series of columns.
#
#     A groupby operation involves some combination of splitting the
#     object, applying a function, and combining the results. This can be
#     used to group large amounts of data and compute operations on these
#     groups.
#
#     Parameters
#     ----------
#     by : mapping, function, label, or list of labels
#         Used to determine the groups for the groupby.
#         If ``by`` is a function, it's called on each value of the object's
#         index. If a dict or Series is passed, the Series or dict VALUES
#         will be used to determine the groups (the Series' values are first
# ...

# %%
df.groupby('Center').mean()
# Out:
#          Measures
# Center
# 1       11.400000
# 2       10.714286

# %%
# Task 8 - Add the following observations to the dataframe
# 'Names': ['Marius', 'Robert', 'Karim'], 'Measures': [15.3, 3.1, 1.5]

new_df = pd.DataFrame({'Measures': [15.3, 3.1, 1.5], 'Center': ['3', '3', '3']}, index = ['Marius', 'Robert', 'Karim'])
df = df.append(new_df)
print(df)
# Out:
#          Measures Center
# Jean         12.5      1
# Marie        18.0      2
# Joseph       10.0      2
# Marthe       13.2      1
# Jacob         3.2      2
# Marc          5.7      2
# Paul         12.0      1
# Pierre        6.0      2
# Ismael        7.0      1
# David        14.5      2
# Mathieu      17.6      2
# Nicolas      12.3      1
# Marius       15.3      3
# Robert        3.1      3
# Karim         1.5      3

# %% [markdown]
# ## **Exercise 2 - DataFrame manipulation**

# %% [markdown]
# **DataFrame.loc | Select column & Row by Name**
#
# DataFrame provides indexing label loc for selecting columns and rows by names
#
# `dataFrame.loc[ROWS RANGE, COLUMNS RANGE]`
#
# **DataFrame.iloc | Select Column indexes & Row index Positions**
#
# DataFrame provides indexing label iloc for accessing the column and rows by index positions i.e.
# `dataFrame.iloc[ROWS INDEX RANGE, COLUMNS INDEX RANGE]`
# it selects the columns and rows from DataFrame by index position specified in range. If ':' is given in rows or column index Range then all entries will be included for corresponding row or column.

# %% [markdown]
# **From the following DataFrame**
#
#
# 1.   Display the first and last 3 rows.
# 2.   Display the column age.
# 3.   Display the number of rows.
# 4.   Display the proportion of male and female patients.
# 5.   Display the 'id' of the youngest and oldest patient along with the corresponding ages.
# 6.   Display all the patients that are over 40 years old
# 7.   Compute the BMI of each pateints and add a new column with this value in your DataFrame.
# 8.   Create a new column with the categorized version of BMI.
# 9.   Display the number of patients in each BMI category.
# 10.  Give the mean age of each category.

# %%
import pandas as pd

df = pd.DataFrame({
  'id': ['085','086','087','088','089','090','091','092','093','094', '95'],
  'age':[19,42,25,58,36,74,65,20,47,32,23],
  'weight':['50', '46', '60', '103','75','68','82', '96','74', '113', '180'],
  'height':[158, 174, 195, 169, 158, 201, 189, 163, 184, 173, 171],
  'sex':['F','F','F','M','M','F','M','F','F','M','F']
})

# %% [markdown]
# **Note 1:** The Body Mass Index (BMI) can be calculated with the formula:
# $$BMI = \frac{Weight}{Height^2}$$
# with the height in meters and the weight in kg.
#
# **Note 2:** We usually categorized the BMI with the following categories:
#
# | Category || BMI (kg/m^2)|
# |---------||:---------|
# | Underweight | Less than 16.0 |
# | Thinness | Between 16.0 and 18.4 |
# | Normal range | Between 18.5 and 24.9|
# | Overweight | Between 25.0 and 29.9|
# | Obese (class I) | Between 30.0 and 34.9 |
# | Obese (class II) | Between 35.0 and 39.9|
# | Obese (class III) | More than 40.0 |

# %% [markdown]
# ## **Correction of Exercise 2**

# %% [markdown]
# #### Task 1 - Display the first and last 3 rows

# %%
# Task 1 - Display the first and last 3 rows
# We can use the method head() that we saw at the last exercise.
df.head(3)
# Out:
#     id  age weight  height sex
# 0  085   19     50     158   F
# 1  086   42     46     174   F
# 2  087   25     60     195   F

# %%
# Or we can use the slicing method
df[:3]
# Out:
#     id  age weight  height sex
# 0  085   19     50     158   F
# 1  086   42     46     174   F
# 2  087   25     60     195   F

# %%
# Or we can use the iloc method
df.iloc[:3,]
# Out:
#     id  age weight  height sex
# 0  085   19     50     158   F
# 1  086   42     46     174   F
# 2  087   25     60     195   F

# %%
# For the last observations there is the tail() method that displays the last 5 observations (default)
df.tail(3)
# Out:
#      id  age weight  height sex
# 8   093   47     74     184   F
# 9   094   32    113     173   M
# 10   95   23    180     171   F

# %%
# Same as before, we can use the slicing
df[-3:]
# Out:
#      id  age weight  height sex
# 8   093   47     74     184   F
# 9   094   32    113     173   M
# 10   95   23    180     171   F

# %%
# Or the iloc method
df.iloc[-3:,]
# Out:
#      id  age weight  height sex
# 8   093   47     74     184   F
# 9   094   32    113     173   M
# 10   95   23    180     171   F

# %% [markdown]
# #### Task 2 - Display the column age

# %%
# We can use the loc method
df.loc[:,'age']
# Out:
# 0     19
# 1     42
# 2     25
# 3     58
# 4     36
# 5     74
# 6     65
# 7     20
# 8     47
# 9     32
# 10    23
# Name: age, dtype: int64

# %%
# Or the iloc method with the index of the column (age is the 2nd column)
df.iloc[:, 1]
# Out:
# 0     19
# 1     42
# 2     25
# 3     58
# 4     36
# 5     74
# 6     65
# 7     20
# 8     47
# 9     32
# 10    23
# Name: age, dtype: int64

# %%
# Or we can use the slicing method
df['age']
# Out:
# 0     19
# 1     42
# 2     25
# 3     58
# 4     36
# 5     74
# 6     65
# 7     20
# 8     47
# 9     32
# 10    23
# Name: age, dtype: int64

# %%
# Or we can even use the '.' to print column (does not work with rows)
df.age
# Out:
# 0     19
# 1     42
# 2     25
# 3     58
# 4     36
# 5     74
# 6     65
# 7     20
# 8     47
# 9     32
# 10    23
# Name: age, dtype: int64

# %% [markdown]
# #### Task 3 - Display the number of rows

# %%
help(pd.DataFrame.shape)
# Out:
# Help on property:
#
#     Return a tuple representing the dimensionality of the DataFrame.
#
#     See Also
#     --------
#     ndarray.shape : Tuple of array dimensions.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
#     >>> df.shape
#     (2, 2)
#
#     >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4],
#     ...                    'col3': [5, 6]})
#     >>> df.shape
#     (2, 3)

# %%
# The shape method returns the dimensions of the dataFrame (# of rows and # of columns)
print(df.shape)

# The first element is the number of rows and the second is the number of columns
print(f'There are {df.shape[0]} rows.')
# Out:
# (11, 5)
# There are 11 rows.

# %% [markdown]
# #### Task 4 - Display the proportion of male and female patients

# %%
# To answer this question we will use the groupby method
print(df.groupby('sex').size(), '\n')

# We can save this value into a new variable
prop = df.groupby('sex').size()/df.shape[0]

# Then display the percentages
prop = round(prop*100, 2)

print(f"There's {prop[0]}% of females and {prop[1]}% of males")
# Out:
# sex
# F    7
# M    4
# dtype: int64
#
# There's 63.64% of females and 36.36% of males

# %% [markdown]
# #### Task 5 - Display the 'id' of the youngest and oldest patient along with the corresponding ages.

# %%
# For that question, we will look into the min and idxmin method 
help(pd.DataFrame.idxmin)
# Out:
# Help on function idxmin in module pandas.core.frame:
#
# idxmin(self, axis: 'Axis' = 0, skipna: 'bool' = True) -> 'Series'
#     Return index of first occurrence of minimum over requested axis.
#
#     NA/null values are excluded.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         The axis to use. 0 or 'index' for row-wise, 1 or 'columns' for column-wise.
#     skipna : bool, default True
#         Exclude NA/null values. If an entire row/column is NA, the result
#         will be NA.
#
#     Returns
#     -------
#     Series
#         Indexes of minima along the specified axis.
#
#     Raises
#     ------
#     ValueError
#         * If the row/column is empty
#
#     See Also
#     --------
#     Series.idxmin : Return index of the minimum element.
#
#     Notes
#     -----
#     This method is the DataFrame version of ``ndarray.argmin``.
#
#     Examples
#     --------
# ...

# %%
df
# Out:
#      id  age weight  height sex
# 0   085   19     50     158   F
# 1   086   42     46     174   F
# 2   087   25     60     195   F
# 3   088   58    103     169   M
# 4   089   36     75     158   M
# 5   090   74     68     201   F
# 6   091   65     82     189   M
# 7   092   20     96     163   F
# 8   093   47     74     184   F
# 9   094   32    113     173   M
# 10   95   23    180     171   F

# %%
# idxmin will return the index of the minimum value of the dataframe
df['age'].idxmin()
# Out:
# 0

# %%
# To automatically print it, we will simultaneously use the iloc method 
row_index_of_the_min = df['age'].idxmin()
df.iloc[row_index_of_the_min, 0]
# Out:
# '085'

# %%
# Or we can also use this syntax
df.id[row_index_of_the_min]
# Out:
# '085'

# %%
print(f"The youngest patient, id n°{df.id[row_index_of_the_min]}, is {df.age[row_index_of_the_min]} years old")
# Out:
# The youngest patient, id n°085, is 19 years old

# %%
# We can do the same for the oldest
row_index_of_the_max = df['age'].idxmax()
print(f"The oldest patient, id n°{df.id[row_index_of_the_max]}, is {df.age[row_index_of_the_max]} years old")
# Out:
# The oldest patient, id n°090, is 74 years old

# %% [markdown]
# #### Task 6 - Display all the patients that are over 40 years old

# %%
# The idea for this question is to first get all the indexes of the patients that are over 40 years and then ask to Python to only print these indexes.

# There are many ways to do it. A naive way could have been to loops through every row,
# use a conditional statement to check the age, 
# save the indexes of the patients that are over 40,
# Then print only theses indexes

# %%
patients_over_40 = list()
n = df.shape[0]

for i in range(0,n):
  if df.age[i] > 40:
    patients_over_40.append(i)
  else:
    next

print(patients_over_40)
print(df.loc[patients_over_40])
# Out:
# [1, 3, 5, 6, 8]
#     id  age weight  height sex
# 1  086   42     46     174   F
# 3  088   58    103     169   M
# 5  090   74     68     201   F
# 6  091   65     82     189   M
# 8  093   47     74     184   F

# %%
# Another way to do it is to use the conditional statement as an one line operation
df['age']>40

# The output is a pandas Series of boolean
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# Name: age, dtype: bool

# %%
type(df['age']> 40)
# Out:
# pandas.core.series.Series

# %%
# You can then use it in a DataFrame
patients_over_40 = df['age'] > 40
df[patients_over_40]
# Out:
#     id  age weight  height sex
# 1  086   42     46     174   F
# 3  088   58    103     169   M
# 5  090   74     68     201   F
# 6  091   65     82     189   M
# 8  093   47     74     184   F

# %%
# In a single line of command
df[df["age"] > 40]
# Out:
#     id  age weight  height sex
# 1  086   42     46     174   F
# 3  088   58    103     169   M
# 5  090   74     68     201   F
# 6  091   65     82     189   M
# 8  093   47     74     184   F

# %% [markdown]
# #### Task 7 - Compute the BMI of each patient and add a column with this value in your DataFrame.

# %% [markdown]
# ```
# # Once again we can answer this question with a for loop
# BMI = list()
#
# for i in range(0, df.shape[0]):
#   height_in_meters = df.height[i]/100
#   weight_as_int = df.weight.astype('int')[i]
#   BMI.append((weight_as_int/(height_in_meters**2)).astype('int'))
#
# df['BMI'] = BMI
# print(df)
#
#     id  age weight  height sex  BMI
# 0  085   19     50     158   F   20
# 1  086   42     46     174   F   15
# 2  087   25     60     195   F   15
# 3  088   58    103     169   M   36
# 4  089   36     75     158   M   30
# 5  090   74     68     201   F   16
# 6  091   65     82     189   M   22
# 7  092   20     96     163   F   36
# 8  093   47     74     184   F   21
# 9  094   32    113     173   M   37
# ```

# %%
# Showing the dataFrame
df
# Out:
#      id  age weight  height sex
# 0   085   19     50     158   F
# 1   086   42     46     174   F
# 2   087   25     60     195   F
# 3   088   58    103     169   M
# 4   089   36     75     158   M
# 5   090   74     68     201   F
# 6   091   65     82     189   M
# 7   092   20     96     163   F
# 8   093   47     74     184   F
# 9   094   32    113     173   M
# 10   95   23    180     171   F

# %%
# We will procede step by step

# First we need to check the units and format of the values 
# The formula asks for a height in meters so we need to convert it to the correct units

df.height/100
# Out:
# 0     1.58
# 1     1.74
# 2     1.95
# 3     1.69
# 4     1.58
# 5     2.01
# 6     1.89
# 7     1.63
# 8     1.84
# 9     1.73
# 10    1.71
# Name: height, dtype: float64

# %%
# Second we need to convert eh weight values
# Indeed by looking at this outcome we can see that the weight value is stored as an 'object', meaning that it is considered as a string here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   age     11 non-null     int64
#  2   weight  11 non-null     object
#  3   height  11 non-null     int64
#  4   sex     11 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 568.0+ bytes

# %%
type(df.weight[0])
# Out:
# str

# %%
# We can convert a DataFrame column with this method
df.weight.astype(int)
# Out:
# 0      50
# 1      46
# 2      60
# 3     103
# 4      75
# 5      68
# 6      82
# 7      96
# 8      74
# 9     113
# 10    180
# Name: weight, dtype: int64

# %%
# It did not modify the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   age     11 non-null     int64
#  2   weight  11 non-null     object
#  3   height  11 non-null     int64
#  4   sex     11 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 568.0+ bytes

# %%
BMI = pd.Series((df.weight.astype(int)/(df.height/100)**2)).astype(float)
new_df = df.assign(BMI = BMI)

# %%
new_df
# Out:
#      id  age weight  height sex        BMI
# 0   085   19     50     158   F  20.028842
# 1   086   42     46     174   F  15.193553
# 2   087   25     60     195   F  15.779093
# 3   088   58    103     169   M  36.063163
# 4   089   36     75     158   M  30.043262
# 5   090   74     68     201   F  16.831267
# 6   091   65     82     189   M  22.955684
# 7   092   20     96     163   F  36.132335
# 8   093   47     74     184   F  21.857278
# 9   094   32    113     173   M  37.756023
# 10   95   23    180     171   F  61.557402

# %%
# With a one line operation
new_df = df.assign(BMI = (df['weight'].astype(int)/((df['height']/100)**2)).astype(float))
new_df
# Out:
#      id  age weight  height sex        BMI
# 0   085   19     50     158   F  20.028842
# 1   086   42     46     174   F  15.193553
# 2   087   25     60     195   F  15.779093
# 3   088   58    103     169   M  36.063163
# 4   089   36     75     158   M  30.043262
# 5   090   74     68     201   F  16.831267
# 6   091   65     82     189   M  22.955684
# 7   092   20     96     163   F  36.132335
# 8   093   47     74     184   F  21.857278
# 9   094   32    113     173   M  37.756023
# 10   95   23    180     171   F  61.557402

# %%
# With a slicing operation
df['BMI'] = ((df['weight'].astype(int))/(df['height']/100)**2).astype(float)
df
# Out:
#      id  age weight  height sex        BMI
# 0   085   19     50     158   F  20.028842
# 1   086   42     46     174   F  15.193553
# 2   087   25     60     195   F  15.779093
# 3   088   58    103     169   M  36.063163
# 4   089   36     75     158   M  30.043262
# 5   090   74     68     201   F  16.831267
# 6   091   65     82     189   M  22.955684
# 7   092   20     96     163   F  36.132335
# 8   093   47     74     184   F  21.857278
# 9   094   32    113     173   M  37.756023
# 10   95   23    180     171   F  61.557402

# %%
help(pd.DataFrame.assign)
# Out:
# Help on function assign in module pandas.core.frame:
#
# assign(self, **kwargs) -> 'DataFrame'
#     Assign new columns to a DataFrame.
#
#     Returns a new object with all original columns in addition to new ones.
#     Existing columns that are re-assigned will be overwritten.
#
#     Parameters
#     ----------
#     **kwargs : dict of {str: callable or Series}
#         The column names are keywords. If the values are
#         callable, they are computed on the DataFrame and
#         assigned to the new columns. The callable must not
#         change input DataFrame (though pandas doesn't check it).
#         If the values are not callable, (e.g. a Series, scalar, or array),
#         they are simply assigned.
#
#     Returns
#     -------
#     DataFrame
#         A new DataFrame with the new columns in addition to
#         all the existing columns.
#
#     Notes
#     -----
#     Assigning multiple columns within the same ``assign`` is possible.
# ...

# %% [markdown]
# #### Task 8 - Create a new column with the categorized version of BMI.

# %%
# For this question we will use the pandas fonction called `cut()`
help(pd.cut)
# Out:
# Help on function cut in module pandas.core.reshape.tile:
#
# cut(x, bins, right: bool = True, labels=None, retbins: bool = False, precision: int = 3, include_lowest: bool = False, duplicates: str = 'raise', ordered: bool = True)
#     Bin values into discrete intervals.
#
#     Use `cut` when you need to segment and sort data values into bins. This
#     function is also useful for going from a continuous variable to a
#     categorical variable. For example, `cut` could convert ages to groups of
#     age ranges. Supports binning into an equal number of bins, or a
#     pre-specified array of bins.
#
#     Parameters
#     ----------
#     x : array-like
#         The input array to be binned. Must be 1-dimensional.
#     bins : int, sequence of scalars, or IntervalIndex
#         The criteria to bin by.
#
#         * int : Defines the number of equal-width bins in the range of `x`. The
#           range of `x` is extended by .1% on each side to include the minimum
# ...

# %%
pd.cut(df.BMI, bins = [0, 16.5, 18.5, 25.0, 30.0, 35.0, 40.0], right = False)
# Out:
# 0     [18.5, 25.0)
# 1      [0.0, 16.5)
# 2      [0.0, 16.5)
# 3     [35.0, 40.0)
# 4     [30.0, 35.0)
# 5     [16.5, 18.5)
# 6     [18.5, 25.0)
# 7     [35.0, 40.0)
# 8     [18.5, 25.0)
# 9     [35.0, 40.0)
# 10             NaN
# Name: BMI, dtype: category
# Categories (6, interval[float64, left]): [[0.0, 16.5) < [16.5, 18.5) < [18.5, 25.0) < [25.0, 30.0) <
#                                           [30.0, 35.0) < [35.0, 40.0)]

# %%
import numpy as np
pd.cut(df.BMI, bins = [0, 16.5, 18.5, 25.0, 30.0, 35.0, 40.0, np.inf])
# You can also use a label for the category, labels= ['Underweight', 'Thinness', 'Normal Range', 'Overweight', 'Obese (Class I)', 'Obese (Class II)', 'Obese (Class III)']
# Out:
# 0     (18.5, 25.0]
# 1      (0.0, 16.5]
# 2      (0.0, 16.5]
# 3     (35.0, 40.0]
# 4     (30.0, 35.0]
# 5     (16.5, 18.5]
# 6     (18.5, 25.0]
# 7     (35.0, 40.0]
# 8     (18.5, 25.0]
# 9     (35.0, 40.0]
# 10     (40.0, inf]
# Name: BMI, dtype: category
# Categories (7, interval[float64, right]): [(0.0, 16.5] < (16.5, 18.5] < (18.5, 25.0] <
#                                            (25.0, 30.0] < (30.0, 35.0] < (35.0, 40.0] <
#                                            (40.0, inf]]

# %%
# You can also use a label for the category,
pd.cut(df.BMI, bins = [0, 16.5, 18.5, 25.0, 30.0, 35.0, 40.0, np.inf], 
       labels= ['Underweight', 'Thinness', 'Normal Range', 'Overweight', 'Obese (Class I)', 'Obese (Class II)', 'Obese (Class III)'])
# Out:
# 0          Normal Range
# 1           Underweight
# 2           Underweight
# 3      Obese (Class II)
# 4       Obese (Class I)
# 5              Thinness
# 6          Normal Range
# 7      Obese (Class II)
# 8          Normal Range
# 9      Obese (Class II)
# 10    Obese (Class III)
# Name: BMI, dtype: category
# Categories (7, object): ['Underweight' < 'Thinness' < 'Normal Range' < 'Overweight' < 'Obese (Class I)' <
#                          'Obese (Class II)' < 'Obese (Class III)']

# %%
df['BMI_cat'] = pd.cut(df.BMI, bins = [0, 16.5, 18.5, 25.0, 30.0, 35.0, 40.0, np.inf])
df
# Out:
#      id  age weight  height sex        BMI       BMI_cat
# 0   085   19     50     158   F  20.028842  (18.5, 25.0]
# 1   086   42     46     174   F  15.193553   (0.0, 16.5]
# 2   087   25     60     195   F  15.779093   (0.0, 16.5]
# 3   088   58    103     169   M  36.063163  (35.0, 40.0]
# 4   089   36     75     158   M  30.043262  (30.0, 35.0]
# 5   090   74     68     201   F  16.831267  (16.5, 18.5]
# 6   091   65     82     189   M  22.955684  (18.5, 25.0]
# 7   092   20     96     163   F  36.132335  (35.0, 40.0]
# 8   093   47     74     184   F  21.857278  (18.5, 25.0]
# 9   094   32    113     173   M  37.756023  (35.0, 40.0]
# 10   95   23    180     171   F  61.557402   (40.0, inf]

# %% [markdown]
# #### Task 9 - Display the number of patients in each BMI category

# %%
df['BMI_cat'].value_counts()
# Out:
# (18.5, 25.0]    3
# (35.0, 40.0]    3
# (0.0, 16.5]     2
# (16.5, 18.5]    1
# (30.0, 35.0]    1
# (40.0, inf]     1
# (25.0, 30.0]    0
# Name: BMI_cat, dtype: int64

# %% [markdown]
# #### Task 10 - Display the mean age of each category

# %%
df.groupby('BMI_cat')['age'].mean()
# Out:
# BMI_cat
# (0.0, 16.5]     33.500000
# (16.5, 18.5]    74.000000
# (18.5, 25.0]    43.666667
# (25.0, 30.0]          NaN
# (30.0, 35.0]    36.000000
# (35.0, 40.0]    36.666667
# (40.0, inf]     23.000000
# Name: age, dtype: float64

# %% [markdown]
# ## **Exercise 3 - Date format**

# %% [markdown]
# For this exercise, we will be using  [HortonGeneralHospital.csv](https://archive.ics.uci.edu/ml/machine-learning-databases/00549/HortonGeneralHospital.csv) a dataset provided on the *UCI Machine Learning Repository*.
#
# In this dataset, we have monthly numbers of transfers from Emergency Room into Critical Care classified in three exclusive categories at Horton General Hospital (Banbury, UK) from November 1999 to May 2011. The three categories are Cardio-respiratory arrest, Respiratory arrest and Hypoglycaemic arrest. You'll also find in this dataset the monthly total number of patients entering Emergency Room.
#
# **Description of variables:**
# * **Cardio**: Numbers of transfers from Emergency Room to Cardio-respiratory arrest.
# * **Resp:** Numbers of transfers from Emergency Room to Respiratory arrest.
# * **Hypo:** Numbers of transfers from Emergency room to Hypoglycaemic arrest.
# * **Adm:** Total number of patients entering Emergency Room.
# * **year:** Year of measurement.
# * **month:** Month of measurement.
#
# **From this data set we will do some date format manipulations.**
#
# 1. **Import the dataset using the url.** (**Hint:** check the `read_csv` pandas' function).
# 2. **Use the dates as an index**
# 3. **Give the date with the most admission to Emergency Room.**
# 4. **How many Hypoglycaemic arrest were recorded for 2004.**
# 5. **From December 2003 to February 2004, use a time function to give you how many days passed**
# 6. **Do a yearly summar of each column. Use the `groupby` function on the index and the agg method to apply a list of function on each column.**
# 6. **Create a new column with a cummulative sum of the Cardio-respiratory arrest**
# 7. **Create a new column with a rolling mean (with a 3 month windows) of the admission to Emergency Room and print the result.**

# %% [markdown]
# ## **Correction of exercise 3**

# %% [markdown]
# #### Task 1 - Import the dataset using the url

# %% [markdown]
# To import a file from a url, we use the pandas read_csv function with the url as an argument. You can use the `help()` function to display al the available arguments of this function.

# %%
import pandas as pd
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %% [markdown]
# The `sep` and `decimal` arguments are very importants. The `sep` defines what will be the separator between columns of the csv file, `decimal` gives the character to recognize as decimal point. For instance in French we use the coma as a decimal and in England it is the point. A file can be badly imported and generate bad analysis if you are not careful enough. Usually the function automatically detect the `sep` and `decimal` used in a csv file. But mistakes can be done with a .txt file for instance. Whatever the file, it is always a good practice to check the importation by using a `head()` function and check the type of variables of your dataset.
#
# Another important argument is how does the NaN values are handled. The `na_values` allows you to specified a scalar or a string which should be assumed as NaN (in addition to NA/NaN). For instance a '-' or 'x' could have been used as a NA values but the importation will consider them as valid values.
#
# `dtypes` allows you to specify the column types with a dictionary. {'<column1>':<typeOfColumn1>,...,'<columnp>':<typeOfColumnp>}.
#
# The `encoding` argument can be useful if some columns contain string with special characters. With the right encoding value, the character will appear correctly in the dataset.
#
# Finally, the `parse_date` argument allows you to specify how do you want to handle the date column. With a `True` argument, all the index will be parse to a date. You can specify which column you want to sparce with a list and you can also specify if you want to merge to column (of dates) into a new column of date format. This argument is what we are interested by with this exercise.

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00549/HortonGeneralHospital.csv"

df = pd.read_csv(filepath_or_buffer = url, sep = ',', decimal = '.', index_col = 1, parse_dates = [[5, 6]])
df.head()
# Out:
#   year_month  Cardio  Resp  Hypo  Adm
# 1 1999-11-01       1     0     0  413
# 2 1999-12-01       1     0     0  443
# 3 2000-01-01       1     0     0  378
# 4 2000-02-01       0     0     0  385
# 5 2000-03-01       1     0     0  388

# %% [markdown]
# #### Task 2 - Use the dates as an index

# %%
# As we saw before for Exercise I, you can use dates as an index in pandas DataFrames
df = df.set_index("year_month")
df
# Out:
#             Cardio  Resp  Hypo  Adm
# year_month
# 1999-11-01       1     0     0  413
# 1999-12-01       1     0     0  443
# 2000-01-01       1     0     0  378
# 2000-02-01       0     0     0  385
# 2000-03-01       1     0     0  388
# 2000-04-01       0     0     0  406
# 2000-05-01       3     0     0  409
# 2000-06-01       0     1     0  425
# 2000-07-01       0     1     0  453
# 2000-08-01       1     0     0  411
# 2000-09-01       1     0     1  407
# 2000-10-01       0     0     0  417
# 2000-11-01       1     0     0  422
# 2000-12-01       1     0     0  426
# 2001-01-01       0     0     0  427
# 2001-02-01       0     0     0  410
# 2001-03-01       1     0     0  450
# 2001-04-01       2     0     1  449
# 2001-05-01       0     0     0  438
# 2001-06-01       0     0     0  446
# 2001-07-01       1     0     1  460
# 2001-08-01       0     0     1  437
# 2001-09-01       0     0     0  475
# 2001-10-01       1     0     0  464
# ...

# %% [markdown]
# #### Task 3 - Give the date with the most admission to Emergency Center.

# %%
# We use the idxmax() method of pandas to get the index of most admission
date_max_adm = df['Adm'].idxmax()
date_max_adm
# Out:
# Timestamp('2004-07-01 00:00:00')

# %%
type(date_max_adm)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
date_max_adm.month_name()
# Out:
# 'July'

# %%
print(f'The maximum number of admissions was reached on {date_max_adm.month_name()} of {date_max_adm.year} with {df.loc[date_max_adm].Adm} admissions')
# Out:
# The maximum number of admissions was reached on July of 2004 with 724 admissions

# %% [markdown]
# #### Task 4 - How many Hypoglycaemic arrests were recorded for 2004

# %%
# First we need to select all the records of 2004
df.loc['2004']
# Out:
#             Cardio  Resp  Hypo  Adm
# year_month
# 2004-01-01       1     2     0  624
# 2004-02-01       3     2     1  553
# 2004-03-01       1     0     0  628
# 2004-04-01       1     0     0  671
# 2004-05-01       1     0     0  713
# 2004-06-01       0     0     0  684
# 2004-07-01       1     1     0  724
# 2004-08-01       1     0     0  655
# 2004-09-01       1     0     1  714
# 2004-10-01       0     0     0  664
# 2004-11-01       1     0     0  589
# 2004-12-01       1     0     0  567

# %%
# Then we need to select records for the Hypo column
df.loc['2004', 'Hypo']
# Out:
# year_month
# 2004-01-01    0
# 2004-02-01    1
# 2004-03-01    0
# 2004-04-01    0
# 2004-05-01    0
# 2004-06-01    0
# 2004-07-01    0
# 2004-08-01    0
# 2004-09-01    1
# 2004-10-01    0
# 2004-11-01    0
# 2004-12-01    0
# Name: Hypo, dtype: int64

# %%
# Lastly, we sum over this column
df.loc['2004', 'Hypo'].sum()
# Out:
# 2

# %%
print('On 2004 there was %i hypoglicaemia arrests in total.' % df.loc['2004', 'Hypo'].sum())
# Out:
# On 2004 there was 2 hypoglicaemia arrests in total.

# %% [markdown]
# #### Task 5 - From December 2003 to February 2004, use a time function to give you how many days passed

# %%
# We can use operators on dates to calculate the number of days between dates.
df.loc['2004-02'].index - df.loc['2003-12'].index # Returns a time delta index
# Out:
# TimedeltaIndex(['62 days'], dtype='timedelta64[ns]', name='year_month', freq=None)

# %%
x = (df.loc['2004-02'].index - df.loc['2003-12'].index)
x.astype(str)
# Out:
# Index(['62 days'], dtype='object', name='year_month')

# %%
print('Between December 2003 and February 2004, there is %s.' % x.astype(str)[0])
# Out:
# Between December 2003 and February 2004, there is 62 days.

# %% [markdown]
# #### Task 6 - Do a yearly summary of each column.

# %%
# We need to yse the groupby method along with index and another method called agg
df.groupby(df.index.year)

# %%
df.groupby(df.index.year).mean()
# Out:
#               Cardio      Resp      Hypo         Adm
# year_month
# 1999        1.000000  0.000000  0.000000  428.000000
# 2000        0.750000  0.166667  0.083333  410.583333
# 2001        0.500000  0.166667  0.250000  451.833333
# 2002        1.250000  0.250000  0.083333  503.916667
# 2003        0.916667  0.583333  0.083333  566.250000
# 2004        1.000000  0.416667  0.166667  648.833333
# 2005        0.833333  0.166667  0.000000  569.166667
# 2006        1.083333  0.250000  0.083333  539.333333
# 2007        0.583333  0.000000  0.000000  543.583333
# 2008        0.833333  0.333333  0.000000  529.000000
# 2009        1.000000  0.333333  0.166667  583.750000
# 2010        0.666667  0.250000  0.083333  575.583333
# 2011        1.000000  0.000000  0.000000  489.000000

# %%
# Using the agg method, will apply the specified function on each column and each group of rows defined by the groupby method
df.groupby(df.index.year).agg('mean')
# Out:
#               Cardio      Resp      Hypo         Adm
# year_month
# 1999        1.000000  0.000000  0.000000  428.000000
# 2000        0.750000  0.166667  0.083333  410.583333
# 2001        0.500000  0.166667  0.250000  451.833333
# 2002        1.250000  0.250000  0.083333  503.916667
# 2003        0.916667  0.583333  0.083333  566.250000
# 2004        1.000000  0.416667  0.166667  648.833333
# 2005        0.833333  0.166667  0.000000  569.166667
# 2006        1.083333  0.250000  0.083333  539.333333
# 2007        0.583333  0.000000  0.000000  543.583333
# 2008        0.833333  0.333333  0.000000  529.000000
# 2009        1.000000  0.333333  0.166667  583.750000
# 2010        0.666667  0.250000  0.083333  575.583333
# 2011        1.000000  0.000000  0.000000  489.000000

# %%
df.groupby(df.index.year).agg(['min', 'mean', 'max', 'std'])
# Out:
#            Cardio                         Resp                         Hypo  \
#               min      mean max       std  min      mean max       std  min
# year_month
# 1999            1  1.000000   1  0.000000    0  0.000000   0  0.000000    0
# 2000            0  0.750000   3  0.866025    0  0.166667   1  0.389249    0
# 2001            0  0.500000   2  0.674200    0  0.166667   1  0.389249    0
# 2002            0  1.250000   3  1.055290    0  0.250000   1  0.452267    0
# 2003            0  0.916667   3  0.996205    0  0.583333   4  1.164500    0
# 2004            0  1.000000   3  0.738549    0  0.416667   2  0.792961    0
# 2005            0  0.833333   2  0.717741    0  0.166667   1  0.389249    0
# 2006            0  1.083333   3  0.996205    0  0.250000   1  0.452267    0
# 2007            0  0.583333   2  0.668558    0  0.000000   0  0.000000    0
# 2008            0  0.833333   3  1.029857    0  0.333333   2  0.651339    0
# ...

# %% [markdown]
# #### Task 7 - Create a new column with a cummulative sum of the Cardio-respiratory arrest

# %%
# To do that we will use the cumsum() method
df.Cardio.cumsum()
# Out:
# year_month
# 1999-11-01      1
# 1999-12-01      2
# 2000-01-01      3
# 2000-02-01      3
# 2000-03-01      4
# 2000-04-01      4
# 2000-05-01      7
# 2000-06-01      7
# 2000-07-01      7
# 2000-08-01      8
# 2000-09-01      9
# 2000-10-01      9
# 2000-11-01     10
# 2000-12-01     11
# 2001-01-01     11
# 2001-02-01     11
# 2001-03-01     12
# 2001-04-01     14
# 2001-05-01     14
# 2001-06-01     14
# 2001-07-01     15
# 2001-08-01     15
# 2001-09-01     15
# 2001-10-01     16
# 2001-11-01     17
# 2001-12-01     17
# 2002-01-01     17
# 2002-02-01     18
# 2002-03-01     19
# 2002-04-01     21
# 2002-05-01     23
# 2002-06-01     23
# 2002-07-01     23
# 2002-08-01     26
# 2002-09-01     28
# 2002-10-01     28
# 2002-11-01     30
# 2002-12-01     32
# 2003-01-01     32
# 2003-02-01     34
# 2003-03-01     35
# 2003-04-01     36
# 2003-05-01     36
# 2003-06-01     36
# 2003-07-01     37
# 2003-08-01     40
# 2003-09-01     41
# 2003-10-01     43
# 2003-11-01     43
# ...

# %%
# Store it into a dataframe column
df['CumSumCardio'] = df.Cardio.cumsum()
df.head()
# Out:
#             Cardio  Resp  Hypo  Adm  CumSumCardio
# year_month
# 1999-11-01       1     0     0  413             1
# 1999-12-01       1     0     0  443             2
# 2000-01-01       1     0     0  378             3
# 2000-02-01       0     0     0  385             3
# 2000-03-01       1     0     0  388             4

# %% [markdown]
# #### Task 8 - Create a new column with a rolling mean (with a 3 month windows) of the admission to Emergency Room and plot the result over the time

# %%
# There's a method in pandas to do so, called rolling
help(pd.DataFrame.rolling)
# Out:
# Help on function rolling in module pandas.core.generic:
#
# rolling(self, window: 'int | timedelta | BaseOffset | BaseIndexer', min_periods: 'int | None' = None, center: 'bool_t' = False, win_type: 'str | None' = None, on: 'str | None' = None, axis: 'Axis' = 0, closed: 'str | None' = None, method: 'str' = 'single')
#     Provide rolling window calculations.
#
#     Parameters
#     ----------
#     window : int, offset, or BaseIndexer subclass
#         Size of the moving window. This is the number of observations used for
#         calculating the statistic. Each window will be a fixed size.
#
#         If its an offset then this will be the time period of each window. Each
#         window will be a variable sized based on the observations included in
#         the time-period. This is only valid for datetimelike indexes.
#
#         If a BaseIndexer subclass is passed, calculates the window boundaries
#         based on the defined ``get_window_bounds`` method. Additional rolling
# ...

# %%
df['MeanWindowAdm'] = df['Adm'].rolling(3).mean()
df
# Out:
#             Cardio  Resp  Hypo  Adm  CumSumCardio  MeanWindowAdm
# year_month
# 1999-11-01       1     0     0  413             1            NaN
# 1999-12-01       1     0     0  443             2            NaN
# 2000-01-01       1     0     0  378             3     411.333333
# 2000-02-01       0     0     0  385             3     402.000000
# 2000-03-01       1     0     0  388             4     383.666667
# 2000-04-01       0     0     0  406             4     393.000000
# 2000-05-01       3     0     0  409             7     401.000000
# 2000-06-01       0     1     0  425             7     413.333333
# 2000-07-01       0     1     0  453             7     429.000000
# 2000-08-01       1     0     0  411             8     429.666667
# 2000-09-01       1     0     1  407             9     423.666667
# 2000-10-01       0     0     0  417             9     411.666667
# 2000-11-01       1     0     0  422            10     415.333333
# ...

# %%
df[['Adm', 'MeanWindowAdm']].plot(style = ['-r', '--b'])
